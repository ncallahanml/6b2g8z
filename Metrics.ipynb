# %%
class TimeMetric():
    def alpha(ret, bench, rfr=0, r_adj=False):
        
    def bet(ret, bench)

# %%
sns.regplot(ret, bench)
beta, alpha = st.linregress(ret, bench)[:2]

# %%
ret = np.asarray(ret)
bench = np.asarray(bench)
dif = ret - bench
print(np.mean(dif))
print(np.std(dif))

# %% [markdown]
# if a benchmark datapoint is below/above its expanding mean, what is the multiplicative factor/linear fit for the compared security below/above that mean?
# how do inflation rates come into this picture?

# %% [markdown]
# [Bayesian MCS](https://www.newfrontieradvisors.com/media/1220/estimation-error-and-portfolio-optimization.pdf)
# [Asymmetric Volatility in Crypto](https://pubmed.ncbi.nlm.nih.gov/33524019/)
# [Asymmetric Volatility Phenomenon](https://www.investopedia.com/terms/a/assymetricvolatility.asp#:~:text=The%20asymmetric%20volatility%20phenomenon%20(AVP)%20is%20the%20observed%20tendency%20of,than%20given%20a%2010%25%20gain.)
# [Equity Market Asymmetric Volatility](https://www0.gsb.columbia.edu/faculty/gbekaert/papers/asymmetric%20volatility.pdf)
# [Bayesian Return Sequences](https://arxiv.org/pdf/2205.01444.pdf)
# [Factor Asset Estimation](https://onlinelibrary.wiley.com/doi/full/10.1002/for.2713)
# [Value Spread](https://joi.pm-research.com/content/early/2021/08/27/joi.2021.1.199/tab-article-info)

# %% [markdown]
# [MVO Forward Returns](https://papers.ssrn.com/sol3/papers.cfm?abstract_id=3046258)
# [CFA Forward Returns](https://www.cfainstitute.org/en/research/cfa-digest/2015/08/portfolio-optimization-using-forward-looking-information-digest-summary)
# [Forward Return Estimates](https://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.233.4998&rep=rep1&type=pdf)
# [Cov Matrix DiffEq](https://www.tandfonline.com/doi/pdf/10.1080/00207169808804700)
# [Differential Covariance Neuroscience](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5726979/)
# [Copula Applications](https://w4.stern.nyu.edu/ioms/docs/sg/seminars/nelsen.pdf)
