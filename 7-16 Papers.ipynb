# %% [markdown]
# #### Volatility Based Kernels and Moving Average Means for Accurate Forecasting with Gaussian Processes
# - [Link](https://paperswithcode.com/paper/volatility-based-kernels-and-moving-average)
# - [PDF](https://arxiv.org/pdf/2207.06544v1.pdf)
# - [Code](https://github.com/g-benton/volt)
# - [Example NB](https://github.com/g-benton/Volt/blob/main/example.ipynb)
# <br>
# <br> Stochastic volatility models are defined with systems of stochastic differential equations, but often lack proper conditioning on historical data to produce true posteriors. This method uses hierarchical Gaussian Processes with specialized covariance functions in place of stochastic volatility models.

# %% [markdown]
# #### Hidden Markov Model from Scratch
# [HMM From Scratch](https://towardsdatascience.com/hidden-markov-model-implemented-from-scratch-72865bda430e)

# %%
import numpy as np

# %%
class StateMatrix():
    def __init__(self, state_matrix=None, probs_matrix=None):
        self.state_matrix = state_matrix
        self.probs_matrix = probs_matrix
        self.states = np.sort(np.unique(state_matrix))
        pass
    
    def __getitem__(self, item):
        
    def __name__(self):
        #not correct
        
    def __add__(self, matrix): #expand matrix forward in time
        self.state_matrix
        
    def add_path(self, path): #add marker for the path that actually occurred
        
    def plot_states(self):
        pass
    
    def plot_probs(self):
        pass
    
    def convert_to_prob():
        probs = np.zeros((len(self.states), self.state_matrix.shape[1]))
        total = self.state_matrix.shape[0]
        for j, col in enumerate(self.state_matrix):
            for i, state in enumerate(self.states):
                probs[i,j] = np.count(state, col) / total
        return probs
    
class StateDisp():
    def __init__(self, state_vrs, state_dict=None):
        self.state_vrs = state_vrs
        if state_dict:
            assert len(state_dict) == state_vrs.shape[3] 
        self.state_dict = state_dict
        return
        
    def __getitem__(self, item):
        if isinstance(item, str):
            assert not state_dict is None, "No Associated State Dictionary"
            assert item in state_dict.keys(), f"Key not in Dictionary"
            index = state_dict[str]
        elif not isinstance(item, int):
            raise TypeError("Type not recognized as indexer")
        val = self.state_vrs[:,:,index]
        return val
    
    def create_matrices(self, state_vrs):
        for state_matrix in split(state_vrs):
            StateMatrix(state_matrix=state_matrix)

# %%
print(slice('a','b','c'))
# Out:
# slice('a', 'b', 'c')
