# %%
from IPython.core.display import display, HTML, Markdown, clear_output
import ipywidgets as widgets

# %% [markdown]
# [](https://medium.com/@technologger/how-to-interact-with-jupyter-33a98686f24e)

# %% [markdown]
# ## Graph All Ticker Paths Without Weights

# %% [markdown]
# ## Graph All Ticker Paths With Weights

# %% [markdown]
# ## Graph Single Ticker Path With Weight

# %% [markdown]
# ## Graph Single Ticker Path Without Weight

# %%
ticker_df = get_etfs_from_db()

tickers = df.columns

# %%
apply_weight = widgets.Checkbox(
    value=False,
    description='Check me',
    disabled=False,
    indent=True,
)

# %%
single_weight = widgets.Dropdown(
    options=[('One', 1), ('Two', 2), ('Three', 3)],
    value=2,
    description='Number:',
)

# %%
widgets.RadioButtons(
    options=['pepperoni', 'pineapple', 'anchovies'],
#    value='pineapple', # Defaults to 'pineapple'
#    layout={'width': 'max-content'}, # If the items' names are long
    description='Pizza topping:',
    disabled=False
)

# %%
widgets.SelectMultiple(
    options=tickers,
    value=tickers[0],
    rows=10,
    description='Tickers',
)

# %%
button = widgets.Button(
    description='Submit',
    disabled=False,
    button_style='success',
    tooltip='Submit',
)
out = widgets.Output()

def button_press(b):
    with out:
        clear_output()
        print("Submitted")
    return

button.on_click(button_press)
widgets.VBox([button, out])

# %%
items = [widgets.Label(str(i)) for i in range(4)]
widgets.Box(items)

# %%
children = [box, box]
# initializing a tab
tab = widgets.Tab()
# setting the tab windows 
tab.children = children
# changing the title of the first and second window
tab.set_title(0, 'box')
tab.set_title(1, 'copy of box')
tab
